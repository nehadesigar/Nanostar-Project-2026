# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from numba import jit

from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import os
from scipy.signal import find_peaks
from scipy.integrate import quad
from scipy.optimize import root_scalar
from matplotlib.animation import PillowWriter, FuncAnimation

# %%
# Independent parameters (free to edit)

Na = 0.5 # Units: M 
T = 303.15 # Units: K
valence = 4
duration = 500 * 10**5 # In timesteps of dt
gridpoints = 128 # Number of points
dx = 10 # Units: nm
dt = 1.E-5 # Units: sec
rho_mean_multicomponent = 6E-5 # Initial mean density of nanostar A, found by spinodal (rho dense + rho dilute)/2 for the value of T used
Cx = 1 #Ratio of AABB nanostars to AAAA and BBBB
save_interval = 10**5
inv_dx2= 1.0 / (dx * dx)


#Establishes constants
K = 1.0E6 # Units: nm^5 
M = 1 # Units: (nm s)^-1

# check effect
B2 = 2190 # Units: nm^3
vb = 1.66 # Units: nm^3


kB = 1.314E-23*0.24 # Units: cal/K (1J=0.24cal)
mol = 6.02E23
dHa = -42000 # Units: cal/mol 
dS1 = 1.84*np.log(Na) # Units: cal/mol K
dS0 = -120 # Units: cal/mol K at 1M NaCl
floor = 1E-12 # Minimum value for arrays
num_saves = duration // save_interval + 1 #Number of saved values

Da = vb * np.exp(-(dHa - T * (dS0 + dS1)) / (mol * kB * T))
Db = Da

# %%
@jit(nopython=True, cache = False) # Converts the given function into machine code (optimization)
def compute_step_three(rhoAAAA, rhoBBBB, rhoAABB):
    
    # Eliminates zeros/negatives
    rhoAAAA_floored = np.maximum(rhoAAAA, floor)
    rhoBBBB_floored = np.maximum(rhoBBBB, floor)
    rhoAABB_floored = np.maximum(rhoAABB, floor)

    # Initializes Xa
    CaDa = 4*(rhoAAAA_floored+0.5*rhoAABB_floored)*Da
    Xa = (-1 + np.sqrt(1 + 4 * CaDa)) / (2 * CaDa)

    #Initializes Xb
    CbDb = 4*(rhoBBBB_floored+0.5*rhoAABB_floored)*Db
    Xb = (-1 + np.sqrt(1 + 4 * CbDb)) / (2 * CbDb)

    # Calculates necessary Laplacians
    laplacian_1d_rhoAAAA = (np.roll(rhoAAAA_floored, -1) - 2.0 * rhoAAAA_floored + np.roll(rhoAAAA_floored, 1)) * inv_dx2
    laplacian_1d_rhoBBBB = (np.roll(rhoBBBB_floored, -1) - 2.0 * rhoBBBB_floored + np.roll(rhoBBBB_floored, 1)) * inv_dx2
    laplacian_1d_rhoAABB = (np.roll(rhoAABB_floored, -1) - 2.0 * rhoAABB_floored + np.roll(rhoAABB_floored, 1)) * inv_dx2

    rho_total = rhoAAAA_floored + rhoBBBB_floored + rhoAABB_floored

    # Total chemical potential of nanostar AAAA (with floored rho, Xa)
    beta_mu_total_AAAA = (2.0 * B2 * rho_total + np.log(rhoAAAA_floored) + #beta mu_ref *** USE RHO TOTAL NOT RHO_i
                        valence * np.log(Xa) - #beta mu_b
                        K * laplacian_1d_rhoAAAA) #beta mu_int
    
    # Total chemical potential of nanostar BBBB (with floored rho, Xa)
    beta_mu_total_BBBB = (2.0 * B2 * rho_total + np.log(rhoBBBB_floored) + #beta mu_ref
                        valence * np.log(Xb) - #beta mu_b
                        K * laplacian_1d_rhoBBBB) #beta mu_int
    
    # Total chemical potential of nanostar AABB (with floored rho, Xa)
    beta_mu_total_AABB = (2.0 * B2 * rho_total + np.log(rhoAABB_floored) + #beta mu_ref
                        (valence/2) * (np.log(Xa) + np.log(Xb)) - #beta mu_b
                        K * laplacian_1d_rhoAABB) #beta mu_int

    # Updates the density for each nanostar explicitly: rho(t+dt) = rho(t) + dt * M laplacian (beta mu_total)
    rhoAAAA_step = dt * M * (np.roll(beta_mu_total_AAAA, -1) - 2.0 * beta_mu_total_AAAA + np.roll(beta_mu_total_AAAA, 1)) * inv_dx2
    rhoBBBB_step = dt * M * (np.roll(beta_mu_total_BBBB, -1) - 2.0 * beta_mu_total_BBBB + np.roll(beta_mu_total_BBBB, 1)) * inv_dx2
    rhoAABB_step = dt * M * (np.roll(beta_mu_total_AABB, -1) - 2.0 * beta_mu_total_AABB + np.roll(beta_mu_total_AABB, 1)) * inv_dx2

    return(rhoAAAA_step, rhoBBBB_step, rhoAABB_step, Xa, Xb)




def calc_free_energy_multicomponent_AB(rho_total_array_AAAA, rho_total_array_BBBB, rho_total_array_AABB, Xa, Xb, v0=1):
    '''
    Finds free energy of a multi-component system using F = integral_V [ f({rho_i}) + K/2 sum_i (gradient rho)^2 ] dV

    Using f_ref = rho_tot * log(v_0 * rho_tot) - rho_tot + B2 * rho_tot^2 + sum_i [rho_i * log(rho_i/rho_tot)]

    Note that the final term IS included in this!

    Using f_b = rho_A * valence * (log(Xa) + (1-Xa)/2) + rho_B * valence * (log(Xb) + (1-Xb)/2) 
              + rho_AB * valence/2 * (log(Xa) + (1-Xa)/2) + rho_AB * valence/2 * (log(Xb) + (1-Xb)/2)
    
    '''

    # Calculates the total density
    rho_tot = rho_total_array_AAAA + rho_total_array_BBBB + rho_total_array_AABB
    
    # To prevent error
    rho_A_floored = np.maximum(rho_total_array_AAAA, floor)
    rho_B_floored = np.maximum(rho_total_array_BBBB, floor)
    rho_AB_floored = np.maximum(rho_total_array_AABB, floor)
    rho_tot_floored = np.maximum(rho_tot, floor)

    # Finds f_ref including the final term
    f_ref = (rho_tot_floored * np.log(v0 * rho_tot_floored) - rho_tot_floored + B2 * rho_tot_floored**2 + 
             rho_A_floored  * np.log(rho_A_floored  / rho_tot_floored) + rho_B_floored  * np.log(rho_B_floored  / rho_tot_floored) + rho_AB_floored * np.log(rho_AB_floored / rho_tot_floored))
    
    # Finds f_b for each component and adds
    f_b = (rho_A_floored  * 4 * (np.log(Xa) + (1-Xa)/2) + rho_B_floored  * 4 * (np.log(Xb) + (1-Xb)/2) + 
           rho_AB_floored * 2 * (np.log(Xa) + (1-Xa)/2) +    rho_AB_floored * 2 * (np.log(Xb) + (1-Xb)/2))
    
    # Finds the free energy at each point (f{rho_i})
    f_local = f_ref + f_b
    
    # Calculates the gradient term K/2 * sum_i (gradient rho_i)^2
    f_gradient = 0.5 * K * ((np.gradient(rho_A_floored, dx))**2 + (np.gradient(rho_B_floored, dx))**2 + (np.gradient(rho_AB_floored, dx))**2)
    
    # Total free energy density
    f_total = f_local + f_gradient
    
    # Integrate over volume in 1D (multiply by dx and sum)
    F_total = np.trapezoid(f_total, dx=dx)
    
    return F_total

# %%
# Initialises system with dilute and dense phases already
def coextanh(gridpoints,rho_dilute,rho_dense,interface_width=5):
    x_values=np.arange(gridpoints)
    return (rho_dilute-rho_dense)*(np.tanh((np.fabs(x_values-gridpoints*0.5)-gridpoints*0.25)/interface_width)+1)/2.+rho_dense

cx_values = list(np.linspace(0, 2, 21))


# Loads Spinodal Data
spinodal_data = np.loadtxt(f"spinodals/f{valence:.1f}")
idx_spinodal = np.argmin(np.abs(spinodal_data[:,0] - T))
rho_spinodal_low  = spinodal_data[idx_spinodal, 1]
rho_spinodal_high = spinodal_data[idx_spinodal, 2]

rho_spinodal_low  = spinodal_data[idx_spinodal, 1]
rho_spinodal_high = spinodal_data[idx_spinodal, 2]

rho_A_final_list = []
rho_B_final_list = []
rho_AB_final_list = []


for cx in cx_values:
    Cx = cx

        
    rhoAAAA = coextanh(gridpoints,rho_spinodal_low,rho_spinodal_high)
    rhoBBBB = np.roll(rhoAAAA, gridpoints//2)

    rho_AB_relative = rhoAAAA * rhoBBBB
    rhoAABB = (rho_AB_relative * cx * np.sum(rhoAAAA))/(np.sum(rho_AB_relative))

    if np.isclose(np.sum(rhoAABB)/np.sum(rhoAAAA), cx) == False:

        print(f"ERROR: CX IS ACTUALLY {np.sum(rhoAABB)/np.sum(rhoAAAA)} not {cx}" )


    # Initializes final rho arrays for graphing
    rho_total_array_AAAA = rhoAAAA 
    rho_total_array_BBBB = rhoBBBB
    rho_total_array_AABB = rhoAABB


    for step in range(duration):

        # Computes a step
        rhoAAAA_step, rhoBBBB_step, rhoAABB_step, Xa, Xb = compute_step_three(rhoAAAA, rhoBBBB, rhoAABB)
        rhoAAAA += rhoAAAA_step
        rhoBBBB += rhoBBBB_step
        rhoAABB += rhoAABB_step

        # Adds the new density to the array of densities + checks mass conservation every 10^5 steps
        if step % (save_interval) == 0:
            rho_total_array_AAAA = np.vstack((rho_total_array_AAAA, rhoAAAA))
            rho_total_array_BBBB = np.vstack((rho_total_array_BBBB, rhoBBBB))
            rho_total_array_AABB = np.vstack((rho_total_array_AABB, rhoAABB))

            
            print(f"Progress: {(step/(save_interval))} out of {duration/(save_interval)} for cx = {cx}")

    rho_A_final_list.append(rhoAAAA)
    rho_B_final_list.append(rhoBBBB)
    rho_AB_final_list.append(rhoAABB)
# Out:
# Progress: 0.0 out of 500.0 for cx = 0.0
# Progress: 1.0 out of 500.0 for cx = 0.0
# Progress: 2.0 out of 500.0 for cx = 0.0
# Progress: 3.0 out of 500.0 for cx = 0.0
# Progress: 4.0 out of 500.0 for cx = 0.0
# Progress: 5.0 out of 500.0 for cx = 0.0
# Progress: 6.0 out of 500.0 for cx = 0.0
# Progress: 7.0 out of 500.0 for cx = 0.0
# Progress: 8.0 out of 500.0 for cx = 0.0
# Progress: 9.0 out of 500.0 for cx = 0.0
# Progress: 10.0 out of 500.0 for cx = 0.0
# Progress: 11.0 out of 500.0 for cx = 0.0
# Progress: 12.0 out of 500.0 for cx = 0.0
# Progress: 13.0 out of 500.0 for cx = 0.0
# Progress: 14.0 out of 500.0 for cx = 0.0
# Progress: 15.0 out of 500.0 for cx = 0.0
# Progress: 16.0 out of 500.0 for cx = 0.0
# Progress: 17.0 out of 500.0 for cx = 0.0
# Progress: 18.0 out of 500.0 for cx = 0.0
# Progress: 19.0 out of 500.0 for cx = 0.0
# Progress: 20.0 out of 500.0 for cx = 0.0
# Progress: 21.0 out of 500.0 for cx = 0.0
# Progress: 22.0 out of 500.0 for cx = 0.0
# Progress: 23.0 out of 500.0 for cx = 0.0
# Progress: 24.0 out of 500.0 for cx = 0.0
# Progress: 25.0 out of 500.0 for cx = 0.0
# Progress: 26.0 out of 500.0 for cx = 0.0
# Progress: 27.0 out of 500.0 for cx = 0.0
# Progress: 28.0 out of 500.0 for cx = 0.0
# Progress: 29.0 out of 500.0 for cx = 0.0
# Progress: 30.0 out of 500.0 for cx = 0.0
# Progress: 31.0 out of 500.0 for cx = 0.0
# Progress: 32.0 out of 500.0 for cx = 0.0
# Progress: 33.0 out of 500.0 for cx = 0.0
# Progress: 34.0 out of 500.0 for cx = 0.0
# Progress: 35.0 out of 500.0 for cx = 0.0
# Progress: 36.0 out of 500.0 for cx = 0.0
# Progress: 37.0 out of 500.0 for cx = 0.0
# Progress: 38.0 out of 500.0 for cx = 0.0
# Progress: 39.0 out of 500.0 for cx = 0.0
# Progress: 40.0 out of 500.0 for cx = 0.0
# Progress: 41.0 out of 500.0 for cx = 0.0
# Progress: 42.0 out of 500.0 for cx = 0.0
# Progress: 43.0 out of 500.0 for cx = 0.0
# Progress: 44.0 out of 500.0 for cx = 0.0
# Progress: 45.0 out of 500.0 for cx = 0.0
# Progress: 46.0 out of 500.0 for cx = 0.0
# Progress: 47.0 out of 500.0 for cx = 0.0
# Progress: 48.0 out of 500.0 for cx = 0.0
# Progress: 49.0 out of 500.0 for cx = 0.0
# Progress: 50.0 out of 500.0 for cx = 0.0
# Progress: 51.0 out of 500.0 for cx = 0.0
# Progress: 52.0 out of 500.0 for cx = 0.0
# Progress: 53.0 out of 500.0 for cx = 0.0
# Progress: 54.0 out of 500.0 for cx = 0.0
# Progress: 55.0 out of 500.0 for cx = 0.0
# Progress: 56.0 out of 500.0 for cx = 0.0
# Progress: 57.0 out of 500.0 for cx = 0.0
# Progress: 58.0 out of 500.0 for cx = 0.0
# Progress: 59.0 out of 500.0 for cx = 0.0
# Progress: 60.0 out of 500.0 for cx = 0.0
# Progress: 61.0 out of 500.0 for cx = 0.0
# Progress: 62.0 out of 500.0 for cx = 0.0
# Progress: 63.0 out of 500.0 for cx = 0.0
# Progress: 64.0 out of 500.0 for cx = 0.0
# Progress: 65.0 out of 500.0 for cx = 0.0
# Progress: 66.0 out of 500.0 for cx = 0.0
# Progress: 67.0 out of 500.0 for cx = 0.0
# Progress: 68.0 out of 500.0 for cx = 0.0
# Progress: 69.0 out of 500.0 for cx = 0.0
# Progress: 70.0 out of 500.0 for cx = 0.0
# Progress: 71.0 out of 500.0 for cx = 0.0
# Progress: 72.0 out of 500.0 for cx = 0.0
# Progress: 73.0 out of 500.0 for cx = 0.0
# Progress: 74.0 out of 500.0 for cx = 0.0
# Progress: 75.0 out of 500.0 for cx = 0.0
# Progress: 76.0 out of 500.0 for cx = 0.0
# Progress: 77.0 out of 500.0 for cx = 0.0
# Progress: 78.0 out of 500.0 for cx = 0.0
# Progress: 79.0 out of 500.0 for cx = 0.0
# Progress: 80.0 out of 500.0 for cx = 0.0
# Progress: 81.0 out of 500.0 for cx = 0.0
# Progress: 82.0 out of 500.0 for cx = 0.0
# Progress: 83.0 out of 500.0 for cx = 0.0
# Progress: 84.0 out of 500.0 for cx = 0.0
# Progress: 85.0 out of 500.0 for cx = 0.0
# Progress: 86.0 out of 500.0 for cx = 0.0
# Progress: 87.0 out of 500.0 for cx = 0.0
# Progress: 88.0 out of 500.0 for cx = 0.0
# Progress: 89.0 out of 500.0 for cx = 0.0
# Progress: 90.0 out of 500.0 for cx = 0.0
# Progress: 91.0 out of 500.0 for cx = 0.0
# Progress: 92.0 out of 500.0 for cx = 0.0
# Progress: 93.0 out of 500.0 for cx = 0.0
# Progress: 94.0 out of 500.0 for cx = 0.0
# Progress: 95.0 out of 500.0 for cx = 0.0
# Progress: 96.0 out of 500.0 for cx = 0.0
# Progress: 97.0 out of 500.0 for cx = 0.0
# Progress: 98.0 out of 500.0 for cx = 0.0
# Progress: 99.0 out of 500.0 for cx = 0.0
# Progress: 100.0 out of 500.0 for cx = 0.0
# Progress: 101.0 out of 500.0 for cx = 0.0
# Progress: 102.0 out of 500.0 for cx = 0.0
# Progress: 103.0 out of 500.0 for cx = 0.0
# Progress: 104.0 out of 500.0 for cx = 0.0
# Progress: 105.0 out of 500.0 for cx = 0.0
# Progress: 106.0 out of 500.0 for cx = 0.0
# Progress: 107.0 out of 500.0 for cx = 0.0
# Progress: 108.0 out of 500.0 for cx = 0.0
# Progress: 109.0 out of 500.0 for cx = 0.0
# Progress: 110.0 out of 500.0 for cx = 0.0
# Progress: 111.0 out of 500.0 for cx = 0.0
# Progress: 112.0 out of 500.0 for cx = 0.0
# Progress: 113.0 out of 500.0 for cx = 0.0
# Progress: 114.0 out of 500.0 for cx = 0.0
# Progress: 115.0 out of 500.0 for cx = 0.0
# Progress: 116.0 out of 500.0 for cx = 0.0
# Progress: 117.0 out of 500.0 for cx = 0.0
# Progress: 118.0 out of 500.0 for cx = 0.0
# Progress: 119.0 out of 500.0 for cx = 0.0
# Progress: 120.0 out of 500.0 for cx = 0.0
# Progress: 121.0 out of 500.0 for cx = 0.0
# Progress: 122.0 out of 500.0 for cx = 0.0
# Progress: 123.0 out of 500.0 for cx = 0.0
# Progress: 124.0 out of 500.0 for cx = 0.0
# Progress: 125.0 out of 500.0 for cx = 0.0
# Progress: 126.0 out of 500.0 for cx = 0.0
# Progress: 127.0 out of 500.0 for cx = 0.0
# Progress: 128.0 out of 500.0 for cx = 0.0
# Progress: 188.0 out of 500.0 for cx = 0.0
# Progress: 189.0 out of 500.0 for cx = 0.0
# Progress: 190.0 out of 500.0 for cx = 0.0
# Progress: 191.0 out of 500.0 for cx = 0.0
# Progress: 192.0 out of 500.0 for cx = 0.0
# Progress: 193.0 out of 500.0 for cx = 0.0
# Progress: 194.0 out of 500.0 for cx = 0.0
# Progress: 195.0 out of 500.0 for cx = 0.0
# Progress: 196.0 out of 500.0 for cx = 0.0
# Progress: 197.0 out of 500.0 for cx = 0.0
# Progress: 198.0 out of 500.0 for cx = 0.0
# Progress: 199.0 out of 500.0 for cx = 0.0
# Progress: 200.0 out of 500.0 for cx = 0.0
# Progress: 201.0 out of 500.0 for cx = 0.0
# Progress: 202.0 out of 500.0 for cx = 0.0
# Progress: 203.0 out of 500.0 for cx = 0.0
# Progress: 204.0 out of 500.0 for cx = 0.0
# Progress: 205.0 out of 500.0 for cx = 0.0
# Progress: 206.0 out of 500.0 for cx = 0.0
# Progress: 207.0 out of 500.0 for cx = 0.0
# Progress: 208.0 out of 500.0 for cx = 0.0
# Progress: 209.0 out of 500.0 for cx = 0.0
# Progress: 210.0 out of 500.0 for cx = 0.0
# Progress: 211.0 out of 500.0 for cx = 0.0
# Progress: 212.0 out of 500.0 for cx = 0.0
# Progress: 213.0 out of 500.0 for cx = 0.0
# Progress: 214.0 out of 500.0 for cx = 0.0
# Progress: 215.0 out of 500.0 for cx = 0.0
# Progress: 216.0 out of 500.0 for cx = 0.0
# Progress: 217.0 out of 500.0 for cx = 0.0
# Progress: 218.0 out of 500.0 for cx = 0.0
# Progress: 219.0 out of 500.0 for cx = 0.0
# Progress: 220.0 out of 500.0 for cx = 0.0
# Progress: 221.0 out of 500.0 for cx = 0.0
# Progress: 222.0 out of 500.0 for cx = 0.0
# Progress: 223.0 out of 500.0 for cx = 0.0
# Progress: 224.0 out of 500.0 for cx = 0.0
# Progress: 225.0 out of 500.0 for cx = 0.0
# Progress: 226.0 out of 500.0 for cx = 0.0
# Progress: 227.0 out of 500.0 for cx = 0.0
# Progress: 228.0 out of 500.0 for cx = 0.0
# Progress: 229.0 out of 500.0 for cx = 0.0
# Progress: 230.0 out of 500.0 for cx = 0.0
# Progress: 231.0 out of 500.0 for cx = 0.0
# Progress: 232.0 out of 500.0 for cx = 0.0
# Progress: 233.0 out of 500.0 for cx = 0.0
# Progress: 234.0 out of 500.0 for cx = 0.0
# Progress: 235.0 out of 500.0 for cx = 0.0
# Progress: 236.0 out of 500.0 for cx = 0.0
# Progress: 237.0 out of 500.0 for cx = 0.0
# Progress: 238.0 out of 500.0 for cx = 0.0
# Progress: 239.0 out of 500.0 for cx = 0.0
# Progress: 240.0 out of 500.0 for cx = 0.0
# Progress: 241.0 out of 500.0 for cx = 0.0
# Progress: 242.0 out of 500.0 for cx = 0.0
# Progress: 243.0 out of 500.0 for cx = 0.0
# Progress: 244.0 out of 500.0 for cx = 0.0
# Progress: 245.0 out of 500.0 for cx = 0.0
# Progress: 246.0 out of 500.0 for cx = 0.0
# Progress: 484.0 out of 500.0 for cx = 0.0
# Progress: 485.0 out of 500.0 for cx = 0.0
# Progress: 486.0 out of 500.0 for cx = 0.0
# Progress: 487.0 out of 500.0 for cx = 0.0
# Progress: 488.0 out of 500.0 for cx = 0.0
# Progress: 489.0 out of 500.0 for cx = 0.0
# Progress: 490.0 out of 500.0 for cx = 0.0
# Progress: 491.0 out of 500.0 for cx = 0.0
# Progress: 492.0 out of 500.0 for cx = 0.0
# Progress: 493.0 out of 500.0 for cx = 0.0
# Progress: 494.0 out of 500.0 for cx = 0.0
# Progress: 495.0 out of 500.0 for cx = 0.0
# Progress: 496.0 out of 500.0 for cx = 0.0
# Progress: 497.0 out of 500.0 for cx = 0.0
# Progress: 498.0 out of 500.0 for cx = 0.0
# Progress: 499.0 out of 500.0 for cx = 0.0
# Progress: 0.0 out of 500.0 for cx = 0.1
# Progress: 1.0 out of 500.0 for cx = 0.1
# Progress: 2.0 out of 500.0 for cx = 0.1
# Progress: 3.0 out of 500.0 for cx = 0.1
# Progress: 4.0 out of 500.0 for cx = 0.1
# Progress: 5.0 out of 500.0 for cx = 0.1
# Progress: 6.0 out of 500.0 for cx = 0.1
# Progress: 7.0 out of 500.0 for cx = 0.1
# Progress: 8.0 out of 500.0 for cx = 0.1
# Progress: 9.0 out of 500.0 for cx = 0.1
# Progress: 10.0 out of 500.0 for cx = 0.1
# Progress: 11.0 out of 500.0 for cx = 0.1
# Progress: 12.0 out of 500.0 for cx = 0.1
# Progress: 13.0 out of 500.0 for cx = 0.1
# Progress: 14.0 out of 500.0 for cx = 0.1
# Progress: 15.0 out of 500.0 for cx = 0.1
# Progress: 16.0 out of 500.0 for cx = 0.1
# Progress: 17.0 out of 500.0 for cx = 0.1
# Progress: 18.0 out of 500.0 for cx = 0.1
# Progress: 19.0 out of 500.0 for cx = 0.1
# Progress: 20.0 out of 500.0 for cx = 0.1
# Progress: 21.0 out of 500.0 for cx = 0.1
# Progress: 22.0 out of 500.0 for cx = 0.1
# Progress: 23.0 out of 500.0 for cx = 0.1
# Progress: 24.0 out of 500.0 for cx = 0.1
# Progress: 25.0 out of 500.0 for cx = 0.1
# Progress: 26.0 out of 500.0 for cx = 0.1
# Progress: 27.0 out of 500.0 for cx = 0.1
# Progress: 28.0 out of 500.0 for cx = 0.1
# Progress: 29.0 out of 500.0 for cx = 0.1
# Progress: 30.0 out of 500.0 for cx = 0.1
# Progress: 31.0 out of 500.0 for cx = 0.1
# Progress: 32.0 out of 500.0 for cx = 0.1
# Progress: 33.0 out of 500.0 for cx = 0.1
# Progress: 34.0 out of 500.0 for cx = 0.1
# Progress: 35.0 out of 500.0 for cx = 0.1
# Progress: 36.0 out of 500.0 for cx = 0.1
# Progress: 37.0 out of 500.0 for cx = 0.1
# Progress: 38.0 out of 500.0 for cx = 0.1
# Progress: 39.0 out of 500.0 for cx = 0.1
# Progress: 40.0 out of 500.0 for cx = 0.1
# Progress: 41.0 out of 500.0 for cx = 0.1
# Progress: 42.0 out of 500.0 for cx = 0.1
# Progress: 43.0 out of 500.0 for cx = 0.1
# Progress: 44.0 out of 500.0 for cx = 0.1
# Progress: 45.0 out of 500.0 for cx = 0.1
# Progress: 46.0 out of 500.0 for cx = 0.1
# Progress: 47.0 out of 500.0 for cx = 0.1
# Progress: 48.0 out of 500.0 for cx = 0.1
# Progress: 49.0 out of 500.0 for cx = 0.1
# Progress: 50.0 out of 500.0 for cx = 0.1
# Progress: 51.0 out of 500.0 for cx = 0.1
# Progress: 52.0 out of 500.0 for cx = 0.1
# Progress: 53.0 out of 500.0 for cx = 0.1
# Progress: 54.0 out of 500.0 for cx = 0.1
# Progress: 55.0 out of 500.0 for cx = 0.1
# Progress: 56.0 out of 500.0 for cx = 0.1
# Progress: 57.0 out of 500.0 for cx = 0.1
# Progress: 58.0 out of 500.0 for cx = 0.1
# Progress: 59.0 out of 500.0 for cx = 0.1
# Progress: 60.0 out of 500.0 for cx = 0.1
# Progress: 61.0 out of 500.0 for cx = 0.1
# Progress: 62.0 out of 500.0 for cx = 0.1
# Progress: 63.0 out of 500.0 for cx = 0.1
# Progress: 64.0 out of 500.0 for cx = 0.1
# Progress: 65.0 out of 500.0 for cx = 0.1
# Progress: 66.0 out of 500.0 for cx = 0.1
# Progress: 67.0 out of 500.0 for cx = 0.1
# Progress: 68.0 out of 500.0 for cx = 0.1
# Progress: 69.0 out of 500.0 for cx = 0.1
# Progress: 70.0 out of 500.0 for cx = 0.1
# Progress: 71.0 out of 500.0 for cx = 0.1
# Progress: 72.0 out of 500.0 for cx = 0.1
# Progress: 73.0 out of 500.0 for cx = 0.1
# Progress: 74.0 out of 500.0 for cx = 0.1
# Progress: 75.0 out of 500.0 for cx = 0.1
# Progress: 76.0 out of 500.0 for cx = 0.1
# Progress: 77.0 out of 500.0 for cx = 0.1
# Progress: 78.0 out of 500.0 for cx = 0.1
# Progress: 79.0 out of 500.0 for cx = 0.1
# Progress: 80.0 out of 500.0 for cx = 0.1
# Progress: 81.0 out of 500.0 for cx = 0.1
# Progress: 82.0 out of 500.0 for cx = 0.1
# Progress: 83.0 out of 500.0 for cx = 0.1
# Progress: 84.0 out of 500.0 for cx = 0.1
# Progress: 85.0 out of 500.0 for cx = 0.1
# Progress: 86.0 out of 500.0 for cx = 0.1
# Progress: 87.0 out of 500.0 for cx = 0.1
# Progress: 88.0 out of 500.0 for cx = 0.1
# Progress: 89.0 out of 500.0 for cx = 0.1
# Progress: 90.0 out of 500.0 for cx = 0.1
# Progress: 91.0 out of 500.0 for cx = 0.1
# Progress: 92.0 out of 500.0 for cx = 0.1
# Progress: 93.0 out of 500.0 for cx = 0.1
# Progress: 94.0 out of 500.0 for cx = 0.1
# Progress: 95.0 out of 500.0 for cx = 0.1
# Progress: 96.0 out of 500.0 for cx = 0.1
# Progress: 97.0 out of 500.0 for cx = 0.1
# Progress: 98.0 out of 500.0 for cx = 0.1
# Progress: 99.0 out of 500.0 for cx = 0.1
# Progress: 100.0 out of 500.0 for cx = 0.1
# Progress: 101.0 out of 500.0 for cx = 0.1
# Progress: 102.0 out of 500.0 for cx = 0.1
# Progress: 103.0 out of 500.0 for cx = 0.1
# Progress: 104.0 out of 500.0 for cx = 0.1
# Progress: 105.0 out of 500.0 for cx = 0.1
# Progress: 106.0 out of 500.0 for cx = 0.1
# Progress: 107.0 out of 500.0 for cx = 0.1
# Progress: 108.0 out of 500.0 for cx = 0.1
# Progress: 109.0 out of 500.0 for cx = 0.1
# Progress: 110.0 out of 500.0 for cx = 0.1
# Progress: 111.0 out of 500.0 for cx = 0.1
# Progress: 112.0 out of 500.0 for cx = 0.1
# Progress: 113.0 out of 500.0 for cx = 0.1
# Progress: 114.0 out of 500.0 for cx = 0.1
# Progress: 115.0 out of 500.0 for cx = 0.1
# Progress: 116.0 out of 500.0 for cx = 0.1
# Progress: 117.0 out of 500.0 for cx = 0.1
# Progress: 118.0 out of 500.0 for cx = 0.1
# Progress: 119.0 out of 500.0 for cx = 0.1
# Progress: 120.0 out of 500.0 for cx = 0.1
# Progress: 121.0 out of 500.0 for cx = 0.1
# Progress: 122.0 out of 500.0 for cx = 0.1
# Progress: 123.0 out of 500.0 for cx = 0.1
# Progress: 124.0 out of 500.0 for cx = 0.1
# Progress: 125.0 out of 500.0 for cx = 0.1
# Progress: 126.0 out of 500.0 for cx = 0.1
# Progress: 127.0 out of 500.0 for cx = 0.1
# Progress: 128.0 out of 500.0 for cx = 0.1
# Progress: 129.0 out of 500.0 for cx = 0.1
# Progress: 130.0 out of 500.0 for cx = 0.1
# Progress: 131.0 out of 500.0 for cx = 0.1
# Progress: 132.0 out of 500.0 for cx = 0.1
# Progress: 133.0 out of 500.0 for cx = 0.1
# Progress: 134.0 out of 500.0 for cx = 0.1
# Progress: 135.0 out of 500.0 for cx = 0.1
# Progress: 136.0 out of 500.0 for cx = 0.1
# Progress: 137.0 out of 500.0 for cx = 0.1
# Progress: 138.0 out of 500.0 for cx = 0.1
# Progress: 139.0 out of 500.0 for cx = 0.1
# Progress: 140.0 out of 500.0 for cx = 0.1
# Progress: 141.0 out of 500.0 for cx = 0.1
# Progress: 142.0 out of 500.0 for cx = 0.1
# Progress: 143.0 out of 500.0 for cx = 0.1
# Progress: 144.0 out of 500.0 for cx = 0.1
# Progress: 145.0 out of 500.0 for cx = 0.1
# Progress: 146.0 out of 500.0 for cx = 0.1
# Progress: 147.0 out of 500.0 for cx = 0.1
# Progress: 148.0 out of 500.0 for cx = 0.1
# Progress: 149.0 out of 500.0 for cx = 0.1
# Progress: 150.0 out of 500.0 for cx = 0.1
# Progress: 151.0 out of 500.0 for cx = 0.1
# Progress: 152.0 out of 500.0 for cx = 0.1
# Progress: 153.0 out of 500.0 for cx = 0.1
# Progress: 154.0 out of 500.0 for cx = 0.1
# Progress: 155.0 out of 500.0 for cx = 0.1
# Progress: 156.0 out of 500.0 for cx = 0.1
# Progress: 157.0 out of 500.0 for cx = 0.1
# Progress: 158.0 out of 500.0 for cx = 0.1
# Progress: 159.0 out of 500.0 for cx = 0.1
# Progress: 160.0 out of 500.0 for cx = 0.1
# Progress: 161.0 out of 500.0 for cx = 0.1
# Progress: 162.0 out of 500.0 for cx = 0.1
# Progress: 163.0 out of 500.0 for cx = 0.1
# Progress: 164.0 out of 500.0 for cx = 0.1
# Progress: 165.0 out of 500.0 for cx = 0.1
# Progress: 166.0 out of 500.0 for cx = 0.1
# Progress: 167.0 out of 500.0 for cx = 0.1
# Progress: 168.0 out of 500.0 for cx = 0.1
# Progress: 169.0 out of 500.0 for cx = 0.1
# Progress: 170.0 out of 500.0 for cx = 0.1
# Progress: 171.0 out of 500.0 for cx = 0.1
# Progress: 172.0 out of 500.0 for cx = 0.1
# Progress: 173.0 out of 500.0 for cx = 0.1
# Progress: 174.0 out of 500.0 for cx = 0.1
# Progress: 175.0 out of 500.0 for cx = 0.1
# Progress: 176.0 out of 500.0 for cx = 0.1
# Progress: 177.0 out of 500.0 for cx = 0.1
# Progress: 178.0 out of 500.0 for cx = 0.1
# Progress: 179.0 out of 500.0 for cx = 0.1
# Progress: 180.0 out of 500.0 for cx = 0.1
# Progress: 181.0 out of 500.0 for cx = 0.1
# Progress: 182.0 out of 500.0 for cx = 0.1
# Progress: 183.0 out of 500.0 for cx = 0.1
# Progress: 184.0 out of 500.0 for cx = 0.1
# Progress: 185.0 out of 500.0 for cx = 0.1
# Progress: 186.0 out of 500.0 for cx = 0.1
# Progress: 187.0 out of 500.0 for cx = 0.1
# Progress: 188.0 out of 500.0 for cx = 0.1
# Progress: 189.0 out of 500.0 for cx = 0.1
# Progress: 190.0 out of 500.0 for cx = 0.1
# Progress: 191.0 out of 500.0 for cx = 0.1
# Progress: 192.0 out of 500.0 for cx = 0.1
# Progress: 193.0 out of 500.0 for cx = 0.1
# Progress: 194.0 out of 500.0 for cx = 0.1
# Progress: 195.0 out of 500.0 for cx = 0.1
# Progress: 196.0 out of 500.0 for cx = 0.1
# Progress: 197.0 out of 500.0 for cx = 0.1
# Progress: 198.0 out of 500.0 for cx = 0.1
# Progress: 199.0 out of 500.0 for cx = 0.1
# Progress: 200.0 out of 500.0 for cx = 0.1
# Progress: 201.0 out of 500.0 for cx = 0.1
# Progress: 202.0 out of 500.0 for cx = 0.1
# Progress: 203.0 out of 500.0 for cx = 0.1
# Progress: 204.0 out of 500.0 for cx = 0.1
# Progress: 205.0 out of 500.0 for cx = 0.1
# Progress: 206.0 out of 500.0 for cx = 0.1
# Progress: 207.0 out of 500.0 for cx = 0.1
# Progress: 208.0 out of 500.0 for cx = 0.1
# Progress: 209.0 out of 500.0 for cx = 0.1
# Progress: 210.0 out of 500.0 for cx = 0.1
# Progress: 211.0 out of 500.0 for cx = 0.1
# Progress: 212.0 out of 500.0 for cx = 0.1
# Progress: 213.0 out of 500.0 for cx = 0.1
# Progress: 214.0 out of 500.0 for cx = 0.1
# Progress: 215.0 out of 500.0 for cx = 0.1
# Progress: 216.0 out of 500.0 for cx = 0.1
# Progress: 217.0 out of 500.0 for cx = 0.1
# Progress: 218.0 out of 500.0 for cx = 0.1
# Progress: 219.0 out of 500.0 for cx = 0.1
# Progress: 220.0 out of 500.0 for cx = 0.1
# Progress: 221.0 out of 500.0 for cx = 0.1
# Progress: 222.0 out of 500.0 for cx = 0.1
# Progress: 223.0 out of 500.0 for cx = 0.1
# Progress: 224.0 out of 500.0 for cx = 0.1
# Progress: 225.0 out of 500.0 for cx = 0.1
# Progress: 226.0 out of 500.0 for cx = 0.1
# Progress: 227.0 out of 500.0 for cx = 0.1
# Progress: 228.0 out of 500.0 for cx = 0.1
# Progress: 229.0 out of 500.0 for cx = 0.1
# Progress: 230.0 out of 500.0 for cx = 0.1
# Progress: 231.0 out of 500.0 for cx = 0.1
# Progress: 232.0 out of 500.0 for cx = 0.1
# Progress: 233.0 out of 500.0 for cx = 0.1
# Progress: 234.0 out of 500.0 for cx = 0.1
# Progress: 235.0 out of 500.0 for cx = 0.1
# Progress: 236.0 out of 500.0 for cx = 0.1
# Progress: 237.0 out of 500.0 for cx = 0.1
# Progress: 238.0 out of 500.0 for cx = 0.1
# Progress: 239.0 out of 500.0 for cx = 0.1
# Progress: 240.0 out of 500.0 for cx = 0.1
# Progress: 241.0 out of 500.0 for cx = 0.1
# Progress: 242.0 out of 500.0 for cx = 0.1
# Progress: 243.0 out of 500.0 for cx = 0.1
# Progress: 244.0 out of 500.0 for cx = 0.1
# Progress: 245.0 out of 500.0 for cx = 0.1
# Progress: 246.0 out of 500.0 for cx = 0.1
# Progress: 247.0 out of 500.0 for cx = 0.1
# Progress: 248.0 out of 500.0 for cx = 0.1
# Progress: 249.0 out of 500.0 for cx = 0.1
# Progress: 250.0 out of 500.0 for cx = 0.1
# Progress: 251.0 out of 500.0 for cx = 0.1
# Progress: 252.0 out of 500.0 for cx = 0.1
# Progress: 253.0 out of 500.0 for cx = 0.1
# Progress: 254.0 out of 500.0 for cx = 0.1
# Progress: 255.0 out of 500.0 for cx = 0.1
# Progress: 256.0 out of 500.0 for cx = 0.1
# Progress: 257.0 out of 500.0 for cx = 0.1
# Progress: 258.0 out of 500.0 for cx = 0.1
# Progress: 259.0 out of 500.0 for cx = 0.1
# Progress: 260.0 out of 500.0 for cx = 0.1
# Progress: 261.0 out of 500.0 for cx = 0.1
# Progress: 262.0 out of 500.0 for cx = 0.1
# Progress: 263.0 out of 500.0 for cx = 0.1
# Progress: 264.0 out of 500.0 for cx = 0.1
# Progress: 265.0 out of 500.0 for cx = 0.1
# Progress: 266.0 out of 500.0 for cx = 0.1
# Progress: 267.0 out of 500.0 for cx = 0.1
# Progress: 268.0 out of 500.0 for cx = 0.1
# Progress: 269.0 out of 500.0 for cx = 0.1
# Progress: 270.0 out of 500.0 for cx = 0.1
# Progress: 271.0 out of 500.0 for cx = 0.1
# Progress: 272.0 out of 500.0 for cx = 0.1
# Progress: 273.0 out of 500.0 for cx = 0.1
# Progress: 274.0 out of 500.0 for cx = 0.1
# Progress: 275.0 out of 500.0 for cx = 0.1
# Progress: 276.0 out of 500.0 for cx = 0.1
# Progress: 277.0 out of 500.0 for cx = 0.1
# Progress: 278.0 out of 500.0 for cx = 0.1
# Progress: 279.0 out of 500.0 for cx = 0.1
# Progress: 280.0 out of 500.0 for cx = 0.1
# Progress: 281.0 out of 500.0 for cx = 0.1
# Progress: 282.0 out of 500.0 for cx = 0.1
# Progress: 283.0 out of 500.0 for cx = 0.1
# Progress: 284.0 out of 500.0 for cx = 0.1
# Progress: 285.0 out of 500.0 for cx = 0.1
# Progress: 286.0 out of 500.0 for cx = 0.1
# Progress: 287.0 out of 500.0 for cx = 0.1
# Progress: 288.0 out of 500.0 for cx = 0.1
# Progress: 289.0 out of 500.0 for cx = 0.1
# Progress: 290.0 out of 500.0 for cx = 0.1
# Progress: 291.0 out of 500.0 for cx = 0.1
# Progress: 292.0 out of 500.0 for cx = 0.1
# Progress: 293.0 out of 500.0 for cx = 0.1
# Progress: 294.0 out of 500.0 for cx = 0.1
# Progress: 295.0 out of 500.0 for cx = 0.1
# Progress: 296.0 out of 500.0 for cx = 0.1
# Progress: 297.0 out of 500.0 for cx = 0.1
# Progress: 298.0 out of 500.0 for cx = 0.1
# Progress: 299.0 out of 500.0 for cx = 0.1
# Progress: 300.0 out of 500.0 for cx = 0.1
# Progress: 301.0 out of 500.0 for cx = 0.1
# Progress: 302.0 out of 500.0 for cx = 0.1
# Progress: 303.0 out of 500.0 for cx = 0.1
# Progress: 304.0 out of 500.0 for cx = 0.1
# Progress: 305.0 out of 500.0 for cx = 0.1
# Progress: 306.0 out of 500.0 for cx = 0.1
# Progress: 307.0 out of 500.0 for cx = 0.1
# Progress: 308.0 out of 500.0 for cx = 0.1
# Progress: 309.0 out of 500.0 for cx = 0.1
# Progress: 310.0 out of 500.0 for cx = 0.1
# Progress: 311.0 out of 500.0 for cx = 0.1
# Progress: 312.0 out of 500.0 for cx = 0.1
# Progress: 313.0 out of 500.0 for cx = 0.1
# Progress: 314.0 out of 500.0 for cx = 0.1
# Progress: 315.0 out of 500.0 for cx = 0.1
# Progress: 316.0 out of 500.0 for cx = 0.1
# Progress: 317.0 out of 500.0 for cx = 0.1
# Progress: 318.0 out of 500.0 for cx = 0.1
# Progress: 319.0 out of 500.0 for cx = 0.1
# Progress: 320.0 out of 500.0 for cx = 0.1
# Progress: 321.0 out of 500.0 for cx = 0.1
# Progress: 322.0 out of 500.0 for cx = 0.1
# Progress: 323.0 out of 500.0 for cx = 0.1
# Progress: 324.0 out of 500.0 for cx = 0.1
# Progress: 325.0 out of 500.0 for cx = 0.1
# Progress: 326.0 out of 500.0 for cx = 0.1
# Progress: 327.0 out of 500.0 for cx = 0.1
# Progress: 328.0 out of 500.0 for cx = 0.1
# Progress: 329.0 out of 500.0 for cx = 0.1
# Progress: 330.0 out of 500.0 for cx = 0.1
# Progress: 331.0 out of 500.0 for cx = 0.1
# Progress: 332.0 out of 500.0 for cx = 0.1
# Progress: 333.0 out of 500.0 for cx = 0.1
# Progress: 334.0 out of 500.0 for cx = 0.1
# Progress: 335.0 out of 500.0 for cx = 0.1
# Progress: 336.0 out of 500.0 for cx = 0.1
# Progress: 337.0 out of 500.0 for cx = 0.1
# Progress: 338.0 out of 500.0 for cx = 0.1
# Progress: 339.0 out of 500.0 for cx = 0.1
# Progress: 340.0 out of 500.0 for cx = 0.1
# Progress: 341.0 out of 500.0 for cx = 0.1
# Progress: 342.0 out of 500.0 for cx = 0.1
# Progress: 343.0 out of 500.0 for cx = 0.1
# Progress: 344.0 out of 500.0 for cx = 0.1
# Progress: 345.0 out of 500.0 for cx = 0.1
# Progress: 346.0 out of 500.0 for cx = 0.1
# Progress: 347.0 out of 500.0 for cx = 0.1
# Progress: 348.0 out of 500.0 for cx = 0.1
# Progress: 349.0 out of 500.0 for cx = 0.1
# Progress: 350.0 out of 500.0 for cx = 0.1
# Progress: 351.0 out of 500.0 for cx = 0.1
# Progress: 352.0 out of 500.0 for cx = 0.1
# Progress: 353.0 out of 500.0 for cx = 0.1
# Progress: 354.0 out of 500.0 for cx = 0.1
# Progress: 355.0 out of 500.0 for cx = 0.1
# Progress: 356.0 out of 500.0 for cx = 0.1
# Progress: 357.0 out of 500.0 for cx = 0.1
# Progress: 358.0 out of 500.0 for cx = 0.1
# Progress: 359.0 out of 500.0 for cx = 0.1
# Progress: 360.0 out of 500.0 for cx = 0.1
# Progress: 361.0 out of 500.0 for cx = 0.1
# Progress: 362.0 out of 500.0 for cx = 0.1
# Progress: 363.0 out of 500.0 for cx = 0.1
# Progress: 364.0 out of 500.0 for cx = 0.1
# Progress: 365.0 out of 500.0 for cx = 0.1
# Progress: 366.0 out of 500.0 for cx = 0.1
# Progress: 367.0 out of 500.0 for cx = 0.1
# Progress: 368.0 out of 500.0 for cx = 0.1
# Progress: 369.0 out of 500.0 for cx = 0.1
# Progress: 370.0 out of 500.0 for cx = 0.1
# Progress: 371.0 out of 500.0 for cx = 0.1
# Progress: 372.0 out of 500.0 for cx = 0.1
# Progress: 373.0 out of 500.0 for cx = 0.1
# Progress: 374.0 out of 500.0 for cx = 0.1
# Progress: 375.0 out of 500.0 for cx = 0.1
# Progress: 376.0 out of 500.0 for cx = 0.1
# Progress: 377.0 out of 500.0 for cx = 0.1
# Progress: 378.0 out of 500.0 for cx = 0.1
# Progress: 379.0 out of 500.0 for cx = 0.1
# Progress: 380.0 out of 500.0 for cx = 0.1
# Progress: 381.0 out of 500.0 for cx = 0.1
# Progress: 382.0 out of 500.0 for cx = 0.1
# Progress: 383.0 out of 500.0 for cx = 0.1
# Progress: 384.0 out of 500.0 for cx = 0.1
# Progress: 385.0 out of 500.0 for cx = 0.1
# Progress: 386.0 out of 500.0 for cx = 0.1
# Progress: 387.0 out of 500.0 for cx = 0.1
# Progress: 388.0 out of 500.0 for cx = 0.1
# Progress: 389.0 out of 500.0 for cx = 0.1
# Progress: 390.0 out of 500.0 for cx = 0.1
# Progress: 391.0 out of 500.0 for cx = 0.1
# Progress: 392.0 out of 500.0 for cx = 0.1
# Progress: 393.0 out of 500.0 for cx = 0.1
# Progress: 394.0 out of 500.0 for cx = 0.1
# Progress: 395.0 out of 500.0 for cx = 0.1
# Progress: 396.0 out of 500.0 for cx = 0.1
# Progress: 397.0 out of 500.0 for cx = 0.1
# Progress: 398.0 out of 500.0 for cx = 0.1
# Progress: 399.0 out of 500.0 for cx = 0.1
# Progress: 400.0 out of 500.0 for cx = 0.1
# Progress: 401.0 out of 500.0 for cx = 0.1
# Progress: 402.0 out of 500.0 for cx = 0.1
# Progress: 403.0 out of 500.0 for cx = 0.1
# Progress: 404.0 out of 500.0 for cx = 0.1
# Progress: 405.0 out of 500.0 for cx = 0.1
# Progress: 406.0 out of 500.0 for cx = 0.1
# Progress: 407.0 out of 500.0 for cx = 0.1
# Progress: 408.0 out of 500.0 for cx = 0.1
# Progress: 409.0 out of 500.0 for cx = 0.1
# Progress: 410.0 out of 500.0 for cx = 0.1
# Progress: 411.0 out of 500.0 for cx = 0.1
# Progress: 412.0 out of 500.0 for cx = 0.1
# Progress: 413.0 out of 500.0 for cx = 0.1
# Progress: 414.0 out of 500.0 for cx = 0.1
# Progress: 415.0 out of 500.0 for cx = 0.1
# Progress: 416.0 out of 500.0 for cx = 0.1
# Progress: 417.0 out of 500.0 for cx = 0.1
# Progress: 418.0 out of 500.0 for cx = 0.1
# Progress: 419.0 out of 500.0 for cx = 0.1
# Progress: 420.0 out of 500.0 for cx = 0.1
# Progress: 421.0 out of 500.0 for cx = 0.1
# Progress: 422.0 out of 500.0 for cx = 0.1
# Progress: 423.0 out of 500.0 for cx = 0.1
# Progress: 424.0 out of 500.0 for cx = 0.1
# Progress: 425.0 out of 500.0 for cx = 0.1
# Progress: 426.0 out of 500.0 for cx = 0.1
# Progress: 427.0 out of 500.0 for cx = 0.1
# Progress: 428.0 out of 500.0 for cx = 0.1
# Progress: 429.0 out of 500.0 for cx = 0.1
# Progress: 430.0 out of 500.0 for cx = 0.1
# Progress: 431.0 out of 500.0 for cx = 0.1
# Progress: 432.0 out of 500.0 for cx = 0.1
# Progress: 433.0 out of 500.0 for cx = 0.1
# Progress: 434.0 out of 500.0 for cx = 0.1
# Progress: 435.0 out of 500.0 for cx = 0.1
# Progress: 436.0 out of 500.0 for cx = 0.1
# Progress: 437.0 out of 500.0 for cx = 0.1
# Progress: 438.0 out of 500.0 for cx = 0.1
# Progress: 439.0 out of 500.0 for cx = 0.1
# Progress: 440.0 out of 500.0 for cx = 0.1
# Progress: 441.0 out of 500.0 for cx = 0.1
# Progress: 442.0 out of 500.0 for cx = 0.1
# Progress: 443.0 out of 500.0 for cx = 0.1
# Progress: 444.0 out of 500.0 for cx = 0.1
# Progress: 445.0 out of 500.0 for cx = 0.1
# Progress: 446.0 out of 500.0 for cx = 0.1
# Progress: 447.0 out of 500.0 for cx = 0.1
# Progress: 448.0 out of 500.0 for cx = 0.1
# Progress: 449.0 out of 500.0 for cx = 0.1
# Progress: 450.0 out of 500.0 for cx = 0.1
# Progress: 451.0 out of 500.0 for cx = 0.1
# Progress: 452.0 out of 500.0 for cx = 0.1
# Progress: 453.0 out of 500.0 for cx = 0.1
# Progress: 454.0 out of 500.0 for cx = 0.1
# Progress: 455.0 out of 500.0 for cx = 0.1
# Progress: 456.0 out of 500.0 for cx = 0.1
# Progress: 457.0 out of 500.0 for cx = 0.1
# Progress: 458.0 out of 500.0 for cx = 0.1
# Progress: 459.0 out of 500.0 for cx = 0.1
# Progress: 460.0 out of 500.0 for cx = 0.1
# Progress: 461.0 out of 500.0 for cx = 0.1
# Progress: 462.0 out of 500.0 for cx = 0.1
# Progress: 463.0 out of 500.0 for cx = 0.1
# Progress: 464.0 out of 500.0 for cx = 0.1
# Progress: 465.0 out of 500.0 for cx = 0.1
# Progress: 466.0 out of 500.0 for cx = 0.1
# Progress: 467.0 out of 500.0 for cx = 0.1
# Progress: 468.0 out of 500.0 for cx = 0.1
# Progress: 469.0 out of 500.0 for cx = 0.1
# Progress: 470.0 out of 500.0 for cx = 0.1
# Progress: 471.0 out of 500.0 for cx = 0.1
# Progress: 472.0 out of 500.0 for cx = 0.1
# Progress: 473.0 out of 500.0 for cx = 0.1
# Progress: 474.0 out of 500.0 for cx = 0.1
# Progress: 475.0 out of 500.0 for cx = 0.1
# Progress: 476.0 out of 500.0 for cx = 0.1
# Progress: 477.0 out of 500.0 for cx = 0.1
# Progress: 478.0 out of 500.0 for cx = 0.1
# Progress: 479.0 out of 500.0 for cx = 0.1
# Progress: 480.0 out of 500.0 for cx = 0.1
# Progress: 481.0 out of 500.0 for cx = 0.1
# Progress: 482.0 out of 500.0 for cx = 0.1
# Progress: 483.0 out of 500.0 for cx = 0.1
# Progress: 484.0 out of 500.0 for cx = 0.1
# Progress: 485.0 out of 500.0 for cx = 0.1
# Progress: 486.0 out of 500.0 for cx = 0.1
# Progress: 487.0 out of 500.0 for cx = 0.1
# Progress: 488.0 out of 500.0 for cx = 0.1
# Progress: 489.0 out of 500.0 for cx = 0.1
# Progress: 490.0 out of 500.0 for cx = 0.1
# Progress: 491.0 out of 500.0 for cx = 0.1
# Progress: 492.0 out of 500.0 for cx = 0.1
# Progress: 493.0 out of 500.0 for cx = 0.1
# Progress: 494.0 out of 500.0 for cx = 0.1
# Progress: 495.0 out of 500.0 for cx = 0.1
# Progress: 496.0 out of 500.0 for cx = 0.1
# Progress: 497.0 out of 500.0 for cx = 0.1
# Progress: 498.0 out of 500.0 for cx = 0.1
# Progress: 499.0 out of 500.0 for cx = 0.1
# Progress: 0.0 out of 500.0 for cx = 0.2
# Progress: 1.0 out of 500.0 for cx = 0.2
# Progress: 2.0 out of 500.0 for cx = 0.2
# Progress: 3.0 out of 500.0 for cx = 0.2
# Progress: 4.0 out of 500.0 for cx = 0.2
# Progress: 5.0 out of 500.0 for cx = 0.2
# Progress: 6.0 out of 500.0 for cx = 0.2
# Progress: 7.0 out of 500.0 for cx = 0.2
# Progress: 8.0 out of 500.0 for cx = 0.2
# Progress: 9.0 out of 500.0 for cx = 0.2
# Progress: 10.0 out of 500.0 for cx = 0.2
# Progress: 11.0 out of 500.0 for cx = 0.2
# Progress: 12.0 out of 500.0 for cx = 0.2
# Progress: 13.0 out of 500.0 for cx = 0.2
# Progress: 14.0 out of 500.0 for cx = 0.2
# Progress: 15.0 out of 500.0 for cx = 0.2
# Progress: 16.0 out of 500.0 for cx = 0.2
# Progress: 17.0 out of 500.0 for cx = 0.2
# Progress: 18.0 out of 500.0 for cx = 0.2
# Progress: 19.0 out of 500.0 for cx = 0.2
# Progress: 20.0 out of 500.0 for cx = 0.2
# Progress: 21.0 out of 500.0 for cx = 0.2
# Progress: 22.0 out of 500.0 for cx = 0.2
# Progress: 23.0 out of 500.0 for cx = 0.2
# Progress: 24.0 out of 500.0 for cx = 0.2
# Progress: 25.0 out of 500.0 for cx = 0.2
# Progress: 26.0 out of 500.0 for cx = 0.2
# Progress: 27.0 out of 500.0 for cx = 0.2
# Progress: 28.0 out of 500.0 for cx = 0.2
# Progress: 29.0 out of 500.0 for cx = 0.2
# Progress: 30.0 out of 500.0 for cx = 0.2
# Progress: 31.0 out of 500.0 for cx = 0.2
# Progress: 32.0 out of 500.0 for cx = 0.2
# Progress: 33.0 out of 500.0 for cx = 0.2
# Progress: 34.0 out of 500.0 for cx = 0.2
# Progress: 35.0 out of 500.0 for cx = 0.2
# Progress: 36.0 out of 500.0 for cx = 0.2
# Progress: 37.0 out of 500.0 for cx = 0.2
# Progress: 38.0 out of 500.0 for cx = 0.2
# Progress: 39.0 out of 500.0 for cx = 0.2
# Progress: 40.0 out of 500.0 for cx = 0.2
# Progress: 41.0 out of 500.0 for cx = 0.2
# Progress: 42.0 out of 500.0 for cx = 0.2
# Progress: 43.0 out of 500.0 for cx = 0.2
# Progress: 44.0 out of 500.0 for cx = 0.2
# Progress: 45.0 out of 500.0 for cx = 0.2
# Progress: 46.0 out of 500.0 for cx = 0.2
# Progress: 47.0 out of 500.0 for cx = 0.2
# Progress: 48.0 out of 500.0 for cx = 0.2
# Progress: 49.0 out of 500.0 for cx = 0.2
# Progress: 50.0 out of 500.0 for cx = 0.2
# Progress: 51.0 out of 500.0 for cx = 0.2
# Progress: 52.0 out of 500.0 for cx = 0.2
# Progress: 53.0 out of 500.0 for cx = 0.2
# Progress: 54.0 out of 500.0 for cx = 0.2
# Progress: 55.0 out of 500.0 for cx = 0.2
# Progress: 56.0 out of 500.0 for cx = 0.2
# Progress: 57.0 out of 500.0 for cx = 0.2
# Progress: 58.0 out of 500.0 for cx = 0.2
# Progress: 59.0 out of 500.0 for cx = 0.2
# Progress: 60.0 out of 500.0 for cx = 0.2
# Progress: 61.0 out of 500.0 for cx = 0.2
# Progress: 62.0 out of 500.0 for cx = 0.2
# Progress: 63.0 out of 500.0 for cx = 0.2
# Progress: 64.0 out of 500.0 for cx = 0.2
# Progress: 65.0 out of 500.0 for cx = 0.2
# Progress: 66.0 out of 500.0 for cx = 0.2
# Progress: 67.0 out of 500.0 for cx = 0.2
# Progress: 68.0 out of 500.0 for cx = 0.2
# Progress: 69.0 out of 500.0 for cx = 0.2
# Progress: 70.0 out of 500.0 for cx = 0.2
# Progress: 71.0 out of 500.0 for cx = 0.2
# Progress: 72.0 out of 500.0 for cx = 0.2
# Progress: 73.0 out of 500.0 for cx = 0.2
# Progress: 74.0 out of 500.0 for cx = 0.2
# Progress: 75.0 out of 500.0 for cx = 0.2
# Progress: 76.0 out of 500.0 for cx = 0.2
# Progress: 77.0 out of 500.0 for cx = 0.2
# Progress: 78.0 out of 500.0 for cx = 0.2
# Progress: 79.0 out of 500.0 for cx = 0.2
# Progress: 80.0 out of 500.0 for cx = 0.2
# Progress: 81.0 out of 500.0 for cx = 0.2
# Progress: 82.0 out of 500.0 for cx = 0.2
# Progress: 83.0 out of 500.0 for cx = 0.2
# Progress: 84.0 out of 500.0 for cx = 0.2
# Progress: 85.0 out of 500.0 for cx = 0.2
# Progress: 86.0 out of 500.0 for cx = 0.2
# Progress: 87.0 out of 500.0 for cx = 0.2
# Progress: 88.0 out of 500.0 for cx = 0.2
# Progress: 89.0 out of 500.0 for cx = 0.2
# Progress: 90.0 out of 500.0 for cx = 0.2
# Progress: 91.0 out of 500.0 for cx = 0.2
# Progress: 92.0 out of 500.0 for cx = 0.2
# Progress: 93.0 out of 500.0 for cx = 0.2
# Progress: 94.0 out of 500.0 for cx = 0.2
# Progress: 95.0 out of 500.0 for cx = 0.2
# Progress: 96.0 out of 500.0 for cx = 0.2
# Progress: 97.0 out of 500.0 for cx = 0.2
# Progress: 98.0 out of 500.0 for cx = 0.2
# Progress: 99.0 out of 500.0 for cx = 0.2
# Progress: 100.0 out of 500.0 for cx = 0.2
# Progress: 101.0 out of 500.0 for cx = 0.2
# Progress: 102.0 out of 500.0 for cx = 0.2
# Progress: 103.0 out of 500.0 for cx = 0.2
# Progress: 104.0 out of 500.0 for cx = 0.2
# Progress: 105.0 out of 500.0 for cx = 0.2
# Progress: 106.0 out of 500.0 for cx = 0.2
# Progress: 107.0 out of 500.0 for cx = 0.2
# Progress: 108.0 out of 500.0 for cx = 0.2
# Progress: 109.0 out of 500.0 for cx = 0.2
# Progress: 110.0 out of 500.0 for cx = 0.2
# Progress: 111.0 out of 500.0 for cx = 0.2
# Progress: 112.0 out of 500.0 for cx = 0.2
# Progress: 113.0 out of 500.0 for cx = 0.2
# Progress: 114.0 out of 500.0 for cx = 0.2
# Progress: 115.0 out of 500.0 for cx = 0.2
# Progress: 116.0 out of 500.0 for cx = 0.2
# Progress: 117.0 out of 500.0 for cx = 0.2
# Progress: 118.0 out of 500.0 for cx = 0.2
# Progress: 119.0 out of 500.0 for cx = 0.2
# Progress: 120.0 out of 500.0 for cx = 0.2
# Progress: 121.0 out of 500.0 for cx = 0.2
# Progress: 122.0 out of 500.0 for cx = 0.2
# Progress: 123.0 out of 500.0 for cx = 0.2
# Progress: 124.0 out of 500.0 for cx = 0.2
# Progress: 125.0 out of 500.0 for cx = 0.2
# Progress: 126.0 out of 500.0 for cx = 0.2
# Progress: 127.0 out of 500.0 for cx = 0.2
# Progress: 128.0 out of 500.0 for cx = 0.2
# Progress: 129.0 out of 500.0 for cx = 0.2
# Progress: 130.0 out of 500.0 for cx = 0.2
# Progress: 131.0 out of 500.0 for cx = 0.2
# Progress: 132.0 out of 500.0 for cx = 0.2
# Progress: 133.0 out of 500.0 for cx = 0.2
# Progress: 134.0 out of 500.0 for cx = 0.2
# Progress: 459.0 out of 500.0 for cx = 2.0
# Progress: 460.0 out of 500.0 for cx = 2.0
# Progress: 461.0 out of 500.0 for cx = 2.0
# Progress: 462.0 out of 500.0 for cx = 2.0
# Progress: 463.0 out of 500.0 for cx = 2.0
# Progress: 464.0 out of 500.0 for cx = 2.0
# Progress: 465.0 out of 500.0 for cx = 2.0
# Progress: 466.0 out of 500.0 for cx = 2.0
# Progress: 467.0 out of 500.0 for cx = 2.0
# Progress: 468.0 out of 500.0 for cx = 2.0
# Progress: 469.0 out of 500.0 for cx = 2.0
# Progress: 470.0 out of 500.0 for cx = 2.0
# Progress: 471.0 out of 500.0 for cx = 2.0
# Progress: 472.0 out of 500.0 for cx = 2.0
# Progress: 473.0 out of 500.0 for cx = 2.0
# Progress: 474.0 out of 500.0 for cx = 2.0
# Progress: 475.0 out of 500.0 for cx = 2.0
# Progress: 476.0 out of 500.0 for cx = 2.0
# Progress: 477.0 out of 500.0 for cx = 2.0
# Progress: 478.0 out of 500.0 for cx = 2.0
# Progress: 479.0 out of 500.0 for cx = 2.0
# Progress: 480.0 out of 500.0 for cx = 2.0
# Progress: 481.0 out of 500.0 for cx = 2.0
# Progress: 482.0 out of 500.0 for cx = 2.0
# Progress: 483.0 out of 500.0 for cx = 2.0
# Progress: 484.0 out of 500.0 for cx = 2.0
# Progress: 485.0 out of 500.0 for cx = 2.0
# Progress: 486.0 out of 500.0 for cx = 2.0
# Progress: 487.0 out of 500.0 for cx = 2.0
# Progress: 488.0 out of 500.0 for cx = 2.0
# Progress: 489.0 out of 500.0 for cx = 2.0
# Progress: 490.0 out of 500.0 for cx = 2.0
# Progress: 491.0 out of 500.0 for cx = 2.0
# Progress: 492.0 out of 500.0 for cx = 2.0
# Progress: 493.0 out of 500.0 for cx = 2.0
# Progress: 494.0 out of 500.0 for cx = 2.0
# Progress: 495.0 out of 500.0 for cx = 2.0
# Progress: 496.0 out of 500.0 for cx = 2.0
# Progress: 497.0 out of 500.0 for cx = 2.0
# Progress: 498.0 out of 500.0 for cx = 2.0
# Progress: 499.0 out of 500.0 for cx = 2.0

# %%
surface_tensions = []


for i, cx in enumerate(cx_values):
    Cx = cx

    rhoAAAA = np.array(rho_A_final_list[i])
    rhoBBBB = np.array(rho_B_final_list[i])
    rhoAABB = np.array(rho_AB_final_list[i])

    _, _, _, Xa, Xb = compute_step_three(rhoAAAA, rhoBBBB, rhoAABB)

    #Takes floored value for densities and finds area of interface for final system
    rho_A_floored = np.maximum(rhoAAAA, floor)
    rho_B_floored = np.maximum(rhoBBBB, floor)
    rho_AB_floored = np.maximum(rhoAABB, floor)
    rho_tot = rhoAAAA + rhoBBBB
    rho_tot_floored = np.maximum(rho_tot, floor)
    A = dx ** 2

    # Extracts dilute/dense phase densities for each component and creates homogeneous systems
    rho_A_dilute = np.min(rho_A_floored) 
    rho_A_dense = np.max(rho_A_floored)
    rho_B_dilute = np.min(rho_B_floored)
    rho_B_dense = np.max(rho_B_floored)
    rho_AB_dilute = np.min(rho_AB_floored)
    rho_AB_dense  = np.max(rho_AB_floored)

    rho_A_dilute_system = np.full(gridpoints, rho_A_dilute)
    rho_A_dense_system = np.full(gridpoints, rho_A_dense)
    rho_B_dilute_system = np.full(gridpoints, rho_B_dilute)
    rho_B_dense_system = np.full(gridpoints, rho_B_dense)
    rho_AB_dilute_system = np.full(gridpoints, rho_AB_dilute)
    rho_AB_dense_system  = np.full(gridpoints, rho_AB_dense)

    # Finds Xa and Xb for dilute, dense, and coex systems

    # For coexisting system
    Xa_final_coex = np.maximum(Xa, floor)
    Xb_final_coex = np.maximum(Xb, floor) 

    # For dilute system
    CaDa_dilute = 4*rho_A_dilute_system*Da 
    CaDa_dilute_floored = np.maximum(CaDa_dilute, floor)
    Xa_final_dilute = (-1 + np.sqrt(1 + 4 * CaDa_dilute_floored)) / (2 * CaDa_dilute_floored)

    CaDb_dilute = 4*rho_B_dilute_system*Db 
    CaDb_dilute_floored = np.maximum(CaDb_dilute, floor)
    Xb_final_dilute = (-1 + np.sqrt(1 + 4 * CaDb_dilute_floored)) / (2 * CaDb_dilute_floored)


    # For dilute system
    CaDa_dilute = 4*(rho_A_dilute_system + 0.5*rho_AB_dilute_system)*Da 
    CaDa_dilute_floored = np.maximum(CaDa_dilute, floor)
    Xa_final_dilute = (-1 + np.sqrt(1 + 4 * CaDa_dilute_floored)) / (2 * CaDa_dilute_floored)

    CaDb_dilute = 4*(rho_B_dilute_system + 0.5*rho_AB_dilute_system)*Db 
    CaDb_dilute_floored = np.maximum(CaDb_dilute, floor)
    Xb_final_dilute = (-1 + np.sqrt(1 + 4 * CaDb_dilute_floored)) / (2 * CaDb_dilute_floored)

    # For dense system
    CaDa_dense = 4*(rho_A_dense_system + 0.5*rho_AB_dense_system)*Da 
    CaDa_dense_floored = np.maximum(CaDa_dense, floor)
    Xa_final_dense = (-1 + np.sqrt(1 + 4 * CaDa_dense_floored)) / (2 * CaDa_dense_floored)

    CaDb_dense = 4*(rho_B_dense_system + 0.5*rho_AB_dense_system)*Db 
    CaDb_dense_floored = np.maximum(CaDb_dense, floor)
    Xb_final_dense = (-1 + np.sqrt(1 + 4 * CaDb_dense_floored)) / (2 * CaDb_dense_floored)

    # Finds free energy of dilute, dense, and coexisting systems
    F_dilute = calc_free_energy_multicomponent_AB(rho_A_dilute_system, rho_B_dilute_system, rho_AB_dilute_system,
                                            Xa_final_dilute, Xb_final_dilute)

    F_dense = calc_free_energy_multicomponent_AB(rho_A_dense_system, rho_B_dense_system, rho_AB_dense_system,
                                            Xa_final_dense, Xb_final_dense)

    F_coex = calc_free_energy_multicomponent_AB(rho_A_floored, rho_B_floored,  rho_AB_floored,
                                        Xa_final_coex, Xb_final_coex)

    # Finds number of interfaces, assuming a proper phase separated final rho using total density
    threshold = (np.min(rho_tot_floored) + np.max(rho_tot_floored)) / 2
    interface_locations = np.where(np.diff((rho_tot > threshold).astype(int)) != 0) #Assigns dilute/dense, then finds changes between them
    interface_count = len(interface_locations[0]) #total number of interfaces (should be 2)

    dilute_fraction = np.sum(rho_tot < threshold) / gridpoints
    dense_fraction = np.sum(rho_tot >= threshold) / gridpoints

    surface_tension = (F_coex - dilute_fraction * F_dilute - dense_fraction * F_dense) / (interface_count * A)    
    print(f"The surface tension is {surface_tension:.6e} for T = {T} in a 1D system with {interface_count} interfaces and 3 components (AAAA, BBBB, and AABB with Cx = {Cx}) initialized with a nonuniform distribution")

    surface_tensions.append(surface_tension)
# Out:
# The surface tension is 6.817440e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.0) initialized with a nonuniform distribution
# The surface tension is 6.707512e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.1) initialized with a nonuniform distribution
# The surface tension is 6.500830e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.2) initialized with a nonuniform distribution
# The surface tension is 5.856974e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.30000000000000004) initialized with a nonuniform distribution
# The surface tension is 5.624963e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.4) initialized with a nonuniform distribution
# The surface tension is 5.444147e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.5) initialized with a nonuniform distribution
# The surface tension is 4.815566e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.6000000000000001) initialized with a nonuniform distribution
# The surface tension is 4.573555e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.7000000000000001) initialized with a nonuniform distribution
# The surface tension is 3.914397e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.8) initialized with a nonuniform distribution
# The surface tension is 3.254261e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 0.9) initialized with a nonuniform distribution
# The surface tension is 2.594700e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.0) initialized with a nonuniform distribution
# The surface tension is 1.666551e-03 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.1) initialized with a nonuniform distribution
# The surface tension is 8.314108e-04 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.2000000000000002) initialized with a nonuniform distribution
# The surface tension is 6.608070e-05 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.3) initialized with a nonuniform distribution
# The surface tension is 2.755415e-06 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.4000000000000001) initialized with a nonuniform distribution
# The surface tension is -9.461173e-08 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.5) initialized with a nonuniform distribution
# The surface tension is 3.557336e-09 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.6) initialized with a nonuniform distribution
# The surface tension is -1.507459e-10 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.7000000000000002) initialized with a nonuniform distribution
# The surface tension is -7.328917e-12 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.8) initialized with a nonuniform distribution
# The surface tension is -4.306222e-13 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 1.9000000000000001) initialized with a nonuniform distribution
# The surface tension is -6.811218e-14 for T = 303.15 in a 1D system with 4 interfaces and 3 components (AAAA, BBBB, and AABB with Cx = 2.0) initialized with a nonuniform distribution

# %%
plt.plot(cx_values, surface_tensions)

plt.xlabel("Relative Crosslinker Concentration")
plt.ylabel(r"Surface Tension (${k_B T}/{n m ^2}$)")
plt.yscale("log")

plt.axhline(0.0015)

# %%
# Initializes x-axis values
x = np.arange(rho_total_array_AAAA.shape[1])

# Picks evenly spaced timesteps to graph
n_snapshots = len(cx_values)

# Makes subplots
fig, axes = plt.subplots(n_snapshots, 1, figsize=(10, 2*n_snapshots), sharex=True)

colors = {"AAAA": "firebrick", "BBBB": "mediumseagreen", "AABB": "darkblue"}

for i in range(n_snapshots):
    ax = axes[i]
    ax.plot(x, rho_A_final_list[i], color=colors["AAAA"], label="AAAA", alpha=0.5)
    ax.plot(x, rho_B_final_list[i], color=colors["BBBB"], label="BBBB", alpha=0.5)
    ax.plot(x, rho_AB_final_list[i], color=colors["AABB"], label="AABB", alpha=0.5)

    ax.set_ylabel("rho (nm⁻³)")
    ax.set_title(f"cx = {cx_values[i]}")
    ax.legend(loc="upper right", fontsize=8)

fig.suptitle("Multiple Component System (A, B, AB), Uniform Initial Distribution")
axes[-1].set_xlabel("Position x")
plt.tight_layout()
plt.show()
